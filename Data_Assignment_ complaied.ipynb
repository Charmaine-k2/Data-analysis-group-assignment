# %% [markdown]
# # DATA ANALYSIS AND VIRTUALIZATION  Group ASSIGNMENT

# %%
# !pip install numpy pandas matplotlib

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # ==========================================================
# # 1. Data Preparation (15 marks)
# # ==========================================================

# %%
import os


print(os.getcwd())
# Out:
# c:\Users\Admin\Downloads\Data analysis group assignment

# %%
#(1a) Load datasets

poverty = pd.read_csv("C:\\Users\\Admin\\Downloads\\Data analysis group assignment\\Datasets\\Poverty_and_Inequality_Platform.csv")
learning_poverty = pd.read_csv("C:\\Users\\Admin\\Downloads\\Data analysis group assignment\\Datasets\\Learning_poverty_global_database.csv")


print("Datasets loaded successfully")
# Out:
# Datasets loaded successfully

# %%
#preview datasets                   
print("\nPoverty dataset sample:")
display(poverty.head())
print("\nLearning Poverty dataset sample:")
display(learning_poverty.head())
# Out:
# Poverty dataset sample:
#        STRUCTURE                STRUCTURE_ID ACTION FREQ FREQ_LABEL REF_AREA  \
# 0  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AGO
# 1  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AGO
# 2  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AGO
# 3  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      ALB
# 4  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      ALB
#
#   REF_AREA_LABEL             INDICATOR  \
# 0         Angola  WB_PIP_HEADCOUNT_IPL
# 1         Angola  WB_PIP_HEADCOUNT_IPL
# 2         Angola  WB_PIP_HEADCOUNT_IPL
# 3        Albania  WB_PIP_HEADCOUNT_IPL
# 4        Albania  WB_PIP_HEADCOUNT_IPL
#
#                                      INDICATOR_LABEL SEX  ... UNIT_MULT_LABEL  \
# 0  Poverty headcount ratio (2017 PPP, $2.15) (% o...  _T  ...           Units
# 1  Poverty headcount ratio (2017 PPP, $2.15) (% o...  _T  ...           Units
# 2  Poverty headcount ratio (2017 PPP, $2.15) (% o...  _T  ...           Units
# 3  Poverty headcount ratio (2017 PPP, $2.15) (% o...  _T  ...           Units
# 4  Poverty headcount ratio (2017 PPP, $2.15) (% o...  _T  ...           Units
#
#   UNIT_TYPE UNIT_TYPE_LABEL TIME_FORMAT TIME_FORMAT_LABEL COMMENT_OBS  \
# 0     RATIO           Ratio         602              CCYY         NaN
# 1     RATIO           Ratio         602              CCYY         NaN
# 2     RATIO           Ratio         602              CCYY         NaN
# 3     RATIO           Ratio         602              CCYY         NaN
# 4     RATIO           Ratio         602              CCYY         NaN
#
#   OBS_STATUS OBS_STATUS_LABEL OBS_CONF OBS_CONF_LABEL
# 0          A     Normal value       PU         Public
# 1          A     Normal value       PU         Public
# 2          A     Normal value       PU         Public
# 3          A     Normal value       PU         Public
# 4          A     Normal value       PU         Public
#
# [5 rows x 38 columns]
# Learning Poverty dataset sample:
#        STRUCTURE                STRUCTURE_ID ACTION FREQ FREQ_LABEL REF_AREA  \
# 0  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AFG
# 1  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AFG
# 2  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AFG
# 3  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AFG
# 4  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      ALB
#
#   REF_AREA_LABEL           INDICATOR                     INDICATOR_LABEL SEX  \
# 0    Afghanistan  WB_LPGD_SE_LPV_POP  Population for Reference Year 2019  _T
# 1    Afghanistan  WB_LPGD_SE_LPV_POP  Population for Reference Year 2019  _T
# 2    Afghanistan  WB_LPGD_SE_LPV_POP  Population for Reference Year 2019  _T
# 3    Afghanistan  WB_LPGD_SE_LPV_POP  Population for Reference Year 2019  _T
# 4        Albania  WB_LPGD_SE_LPV_POP  Population for Reference Year 2019  _T
#
#    ... UNIT_MULT UNIT_MULT_LABEL UNIT_TYPE  UNIT_TYPE_LABEL TIME_FORMAT  \
# 0  ...         0           Units     COUNT  Count (Integer)         602
# 1  ...         0           Units     COUNT  Count (Integer)         602
# 2  ...         0           Units     COUNT  Count (Integer)         602
# 3  ...         0           Units     COUNT  Count (Integer)         602
# 4  ...         0           Units     COUNT  Count (Integer)         602
#
#   TIME_FORMAT_LABEL OBS_STATUS OBS_STATUS_LABEL OBS_CONF OBS_CONF_LABEL
# 0              CCYY          A     Normal value       PU         Public
# 1              CCYY          A     Normal value       PU         Public
# 2              CCYY          A     Normal value       PU         Public
# 3              CCYY          A     Normal value       PU         Public
# 4              CCYY          A     Normal value       PU         Public
#
# [5 rows x 37 columns]

# %%
# (1b) Dataset info
print("\n--- Dataset Info ---")
poverty.info()
learning_poverty.info()
# Out:
# --- Dataset Info ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29973 entries, 0 to 29972
# Data columns (total 38 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   STRUCTURE               29973 non-null  object
#  1   STRUCTURE_ID            29973 non-null  object
#  2   ACTION                  29973 non-null  object
#  3   FREQ                    29973 non-null  object
#  4   FREQ_LABEL              29973 non-null  object
#  5   REF_AREA                29973 non-null  object
#  6   REF_AREA_LABEL          29973 non-null  object
#  7   INDICATOR               29973 non-null  object
#  8   INDICATOR_LABEL         29973 non-null  object
#  9   SEX                     29973 non-null  object
#  10  SEX_LABEL               29973 non-null  object
#  11  AGE                     29973 non-null  object
#  12  AGE_LABEL               29973 non-null  object
#  13  URBANISATION            29973 non-null  object
#  14  URBANISATION_LABEL      29973 non-null  object
#  15  UNIT_MEASURE            29973 non-null  object
#  16  UNIT_MEASURE_LABEL      29973 non-null  object
#  17  COMP_BREAKDOWN_1        29973 non-null  object
#  18  COMP_BREAKDOWN_1_LABEL  29973 non-null  object
#  19  COMP_BREAKDOWN_2        29973 non-null  object
#  20  COMP_BREAKDOWN_2_LABEL  29973 non-null  object
#  21  COMP_BREAKDOWN_3        29973 non-null  object
#  22  COMP_BREAKDOWN_3_LABEL  29973 non-null  object
#  23  TIME_PERIOD             29973 non-null  int64
#  24  OBS_VALUE               29973 non-null  float64
#  25  DATABASE_ID             29973 non-null  object
#  26  DATABASE_ID_LABEL       29973 non-null  object
#  27  UNIT_MULT               29973 non-null  int64
#  28  UNIT_MULT_LABEL         29973 non-null  object
#  29  UNIT_TYPE               29973 non-null  object
#  30  UNIT_TYPE_LABEL         29973 non-null  object
#  31  TIME_FORMAT             29973 non-null  int64
#  32  TIME_FORMAT_LABEL       29973 non-null  object
#  33  COMMENT_OBS             0 non-null      float64
#  34  OBS_STATUS              29973 non-null  object
#  35  OBS_STATUS_LABEL        29973 non-null  object
#  36  OBS_CONF                29973 non-null  object
#  37  OBS_CONF_LABEL          29973 non-null  object
# dtypes: float64(2), int64(3), object(33)
# memory usage: 8.7+ MB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9329 entries, 0 to 9328
# Data columns (total 37 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   STRUCTURE               9329 non-null   object
#  1   STRUCTURE_ID            9329 non-null   object
#  2   ACTION                  9329 non-null   object
#  3   FREQ                    9329 non-null   object
#  4   FREQ_LABEL              9329 non-null   object
#  5   REF_AREA                9329 non-null   object
#  6   REF_AREA_LABEL          9329 non-null   object
#  7   INDICATOR               9329 non-null   object
#  8   INDICATOR_LABEL         9329 non-null   object
#  9   SEX                     9329 non-null   object
#  10  SEX_LABEL               9329 non-null   object
#  11  AGE                     9329 non-null   object
#  12  AGE_LABEL               9329 non-null   object
#  13  URBANISATION            9329 non-null   object
#  14  URBANISATION_LABEL      9329 non-null   object
#  15  UNIT_MEASURE            9329 non-null   object
#  16  UNIT_MEASURE_LABEL      9329 non-null   object
#  17  COMP_BREAKDOWN_1        9329 non-null   object
#  18  COMP_BREAKDOWN_1_LABEL  9329 non-null   object
#  19  COMP_BREAKDOWN_2        9329 non-null   object
#  20  COMP_BREAKDOWN_2_LABEL  9329 non-null   object
#  21  COMP_BREAKDOWN_3        9329 non-null   object
#  22  COMP_BREAKDOWN_3_LABEL  9329 non-null   object
#  23  TIME_PERIOD             9329 non-null   int64
#  24  OBS_VALUE               9329 non-null   float64
#  25  DATABASE_ID             9329 non-null   object
#  26  DATABASE_ID_LABEL       9329 non-null   object
#  27  UNIT_MULT               9329 non-null   int64
#  28  UNIT_MULT_LABEL         9329 non-null   object
#  29  UNIT_TYPE               9329 non-null   object
#  30  UNIT_TYPE_LABEL         9329 non-null   object
#  31  TIME_FORMAT             9329 non-null   int64
#  32  TIME_FORMAT_LABEL       9329 non-null   object
#  33  OBS_STATUS              9329 non-null   object
#  34  OBS_STATUS_LABEL        9329 non-null   object
#  35  OBS_CONF                9329 non-null   object
#  36  OBS_CONF_LABEL          9329 non-null   object
# dtypes: float64(1), int64(3), object(33)
# memory usage: 2.6+ MB

# %%
# (1c) Handle missing values
print("\nMissing values in Poverty dataset:")
print(poverty.isnull().sum())

print("\nMissing values in Learning Poverty dataset:")
print(learning_poverty.isnull().sum())

print("\nPoverty dataset stats:")
display(poverty.describe(include="all"))

print("\nLearning Poverty dataset stats:")
display(learning_poverty.describe(include="all"))
# Out:
# Missing values in Poverty dataset:
# STRUCTURE                     0
# STRUCTURE_ID                  0
# ACTION                        0
# FREQ                          0
# FREQ_LABEL                    0
# REF_AREA                      0
# REF_AREA_LABEL                0
# INDICATOR                     0
# INDICATOR_LABEL               0
# SEX                           0
# SEX_LABEL                     0
# AGE                           0
# AGE_LABEL                     0
# URBANISATION                  0
# URBANISATION_LABEL            0
# UNIT_MEASURE                  0
# UNIT_MEASURE_LABEL            0
# COMP_BREAKDOWN_1              0
# COMP_BREAKDOWN_1_LABEL        0
# COMP_BREAKDOWN_2              0
# COMP_BREAKDOWN_2_LABEL        0
# COMP_BREAKDOWN_3              0
# COMP_BREAKDOWN_3_LABEL        0
# TIME_PERIOD                   0
# OBS_VALUE                     0
# DATABASE_ID                   0
# DATABASE_ID_LABEL             0
# UNIT_MULT                     0
# UNIT_MULT_LABEL               0
# UNIT_TYPE                     0
# UNIT_TYPE_LABEL               0
# TIME_FORMAT                   0
# TIME_FORMAT_LABEL             0
# COMMENT_OBS               29973
# OBS_STATUS                    0
# OBS_STATUS_LABEL              0
# OBS_CONF                      0
# OBS_CONF_LABEL                0
# dtype: int64
#
# Missing values in Learning Poverty dataset:
# STRUCTURE                 0
# STRUCTURE_ID              0
# ACTION                    0
# FREQ                      0
# FREQ_LABEL                0
# REF_AREA                  0
# REF_AREA_LABEL            0
# INDICATOR                 0
# INDICATOR_LABEL           0
# SEX                       0
# SEX_LABEL                 0
# AGE                       0
# AGE_LABEL                 0
# URBANISATION              0
# URBANISATION_LABEL        0
# UNIT_MEASURE              0
# UNIT_MEASURE_LABEL        0
# COMP_BREAKDOWN_1          0
# COMP_BREAKDOWN_1_LABEL    0
# COMP_BREAKDOWN_2          0
# COMP_BREAKDOWN_2_LABEL    0
# COMP_BREAKDOWN_3          0
# COMP_BREAKDOWN_3_LABEL    0
# TIME_PERIOD               0
# OBS_VALUE                 0
# DATABASE_ID               0
# DATABASE_ID_LABEL         0
# UNIT_MULT                 0
# UNIT_MULT_LABEL           0
# UNIT_TYPE                 0
# UNIT_TYPE_LABEL           0
# TIME_FORMAT               0
# TIME_FORMAT_LABEL         0
# OBS_STATUS                0
# OBS_STATUS_LABEL          0
# OBS_CONF                  0
# OBS_CONF_LABEL            0
# dtype: int64
#
# Poverty dataset stats:
#             STRUCTURE                STRUCTURE_ID ACTION   FREQ FREQ_LABEL  \
# count           29973                       29973  29973  29973      29973
# unique              1                           1      1      1          1
# top     datastructure  WB.DATA360:DS_DATA360(1.2)      I      A     Annual
# freq            29973                       29973  29973  29973      29973
# mean              NaN                         NaN    NaN    NaN        NaN
# std               NaN                         NaN    NaN    NaN        NaN
# min               NaN                         NaN    NaN    NaN        NaN
# 25%               NaN                         NaN    NaN    NaN        NaN
# 50%               NaN                         NaN    NaN    NaN        NaN
# 75%               NaN                         NaN    NaN    NaN        NaN
# max               NaN                         NaN    NaN    NaN        NaN
#
#        REF_AREA REF_AREA_LABEL          INDICATOR  \
# count     29973          29973              29973
# unique      184            184                  6
# top         USA  United States  WB_PIP_NPOOR_LMIC
# freq        720            720               5067
# mean        NaN            NaN                NaN
# std         NaN            NaN                NaN
# min         NaN            NaN                NaN
# 25%         NaN            NaN                NaN
# 50%         NaN            NaN                NaN
# 75%         NaN            NaN                NaN
# max         NaN            NaN                NaN
#
#                                           INDICATOR_LABEL    SEX  ...  \
# count                                               29973  29973  ...
# unique                                                  6      1  ...
# top     Population living below the poverty line (2017...     _T  ...
# freq                                                 5067  29973  ...
# mean                                                  NaN    NaN  ...
# std                                                   NaN    NaN  ...
# min                                                   NaN    NaN  ...
# 25%                                                   NaN    NaN  ...
# 50%                                                   NaN    NaN  ...
# 75%                                                   NaN    NaN  ...
# max                                                   NaN    NaN  ...
#
#        UNIT_MULT_LABEL UNIT_TYPE       UNIT_TYPE_LABEL TIME_FORMAT  \
# count            29973     29973                 29973     29973.0
# unique               2         2                     2         NaN
# top           Millions    NUMBER  Number (real number)         NaN
# freq             15201     15201                 15201         NaN
# mean               NaN       NaN                   NaN       602.0
# std                NaN       NaN                   NaN         0.0
# min                NaN       NaN                   NaN       602.0
# 25%                NaN       NaN                   NaN       602.0
# 50%                NaN       NaN                   NaN       602.0
# 75%                NaN       NaN                   NaN       602.0
# max                NaN       NaN                   NaN       602.0
#
#        TIME_FORMAT_LABEL COMMENT_OBS OBS_STATUS OBS_STATUS_LABEL OBS_CONF  \
# count              29973         0.0      29973            29973    29973
# unique                 1         NaN          1                1        1
# top                 CCYY         NaN          A     Normal value       PU
# freq               29973         NaN      29973            29973    29973
# mean                 NaN         NaN        NaN              NaN      NaN
# std                  NaN         NaN        NaN              NaN      NaN
# min                  NaN         NaN        NaN              NaN      NaN
# 25%                  NaN         NaN        NaN              NaN      NaN
# 50%                  NaN         NaN        NaN              NaN      NaN
# 75%                  NaN         NaN        NaN              NaN      NaN
# max                  NaN         NaN        NaN              NaN      NaN
#
#        OBS_CONF_LABEL
# count           29973
# unique              1
# top            Public
# freq            29973
# mean              NaN
# std               NaN
# min               NaN
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max               NaN
#
# [11 rows x 38 columns]
# Learning Poverty dataset stats:
#             STRUCTURE                STRUCTURE_ID ACTION  FREQ FREQ_LABEL  \
# count            9329                        9329   9329  9329       9329
# unique              1                           1      1     1          1
# top     datastructure  WB.DATA360:DS_DATA360(1.2)      I     A     Annual
# freq             9329                        9329   9329  9329       9329
# mean              NaN                         NaN    NaN   NaN        NaN
# std               NaN                         NaN    NaN   NaN        NaN
# min               NaN                         NaN    NaN   NaN        NaN
# 25%               NaN                         NaN    NaN   NaN        NaN
# 50%               NaN                         NaN    NaN   NaN        NaN
# 75%               NaN                         NaN    NaN   NaN        NaN
# max               NaN                         NaN    NaN   NaN        NaN
#
#        REF_AREA REF_AREA_LABEL           INDICATOR  \
# count      9329           9329                9329
# unique      125            125                   9
# top         ARM        Armenia  WB_LPGD_SE_LPV_POP
# freq        180            180                3154
# mean        NaN            NaN                 NaN
# std         NaN            NaN                 NaN
# min         NaN            NaN                 NaN
# 25%         NaN            NaN                 NaN
# 50%         NaN            NaN                 NaN
# 75%         NaN            NaN                 NaN
# max         NaN            NaN                 NaN
#
#                            INDICATOR_LABEL   SEX  ... UNIT_MULT  \
# count                                 9329  9329  ...    9329.0
# unique                                   9     3  ...       NaN
# top     Population for Reference Year 2019    _T  ...       NaN
# freq                                  3154  3663  ...       NaN
# mean                                   NaN   NaN  ...       0.0
# std                                    NaN   NaN  ...       0.0
# min                                    NaN   NaN  ...       0.0
# 25%                                    NaN   NaN  ...       0.0
# 50%                                    NaN   NaN  ...       0.0
# 75%                                    NaN   NaN  ...       0.0
# max                                    NaN   NaN  ...       0.0
#
#        UNIT_MULT_LABEL UNIT_TYPE UNIT_TYPE_LABEL TIME_FORMAT  \
# count             9329      9329            9329      9329.0
# unique               1         2               2         NaN
# top              Units     RATIO           Ratio         NaN
# freq              9329      5401            5401         NaN
# mean               NaN       NaN             NaN       602.0
# std                NaN       NaN             NaN         0.0
# min                NaN       NaN             NaN       602.0
# 25%                NaN       NaN             NaN       602.0
# 50%                NaN       NaN             NaN       602.0
# 75%                NaN       NaN             NaN       602.0
# max                NaN       NaN             NaN       602.0
#
#        TIME_FORMAT_LABEL OBS_STATUS OBS_STATUS_LABEL OBS_CONF OBS_CONF_LABEL
# count               9329       9329             9329     9329           9329
# unique                 1          1                1        1              1
# top                 CCYY          A     Normal value       PU         Public
# freq                9329       9329             9329     9329           9329
# mean                 NaN        NaN              NaN      NaN            NaN
# std                  NaN        NaN              NaN      NaN            NaN
# min                  NaN        NaN              NaN      NaN            NaN
# 25%                  NaN        NaN              NaN      NaN            NaN
# 50%                  NaN        NaN              NaN      NaN            NaN
# 75%                  NaN        NaN              NaN      NaN            NaN
# max                  NaN        NaN              NaN      NaN            NaN
#
# [11 rows x 37 columns]

# %%
#cleaning data


poverty_clean = poverty[['REF_AREA_LABEL', 'TIME_PERIOD', 'INDICATOR_LABEL', 'OBS_VALUE']].copy()
poverty_clean['OBS_VALUE'] = pd.to_numeric(poverty_clean['OBS_VALUE'], errors='coerce')
poverty_clean.dropna(subset=['OBS_VALUE'], inplace=True)


learning_clean = learning_poverty[['REF_AREA_LABEL', 'TIME_PERIOD', 'INDICATOR_LABEL', 'OBS_VALUE']].copy()
learning_clean['OBS_VALUE'] = pd.to_numeric(learning_clean['OBS_VALUE'], errors='coerce')
learning_clean.dropna(subset=['OBS_VALUE'], inplace=True)

# %%
# Inspecting poverty dataset
print(poverty.columns)
print(poverty.head())

# Inspecting learning dataset
print(learning_poverty.columns)
print(learning_poverty.head())
# Out:
# Index(['STRUCTURE', 'STRUCTURE_ID', 'ACTION', 'FREQ', 'FREQ_LABEL', 'REF_AREA',
#        'REF_AREA_LABEL', 'INDICATOR', 'INDICATOR_LABEL', 'SEX', 'SEX_LABEL',
#        'AGE', 'AGE_LABEL', 'URBANISATION', 'URBANISATION_LABEL',
#        'UNIT_MEASURE', 'UNIT_MEASURE_LABEL', 'COMP_BREAKDOWN_1',
#        'COMP_BREAKDOWN_1_LABEL', 'COMP_BREAKDOWN_2', 'COMP_BREAKDOWN_2_LABEL',
#        'COMP_BREAKDOWN_3', 'COMP_BREAKDOWN_3_LABEL', 'TIME_PERIOD',
#        'OBS_VALUE', 'DATABASE_ID', 'DATABASE_ID_LABEL', 'UNIT_MULT',
#        'UNIT_MULT_LABEL', 'UNIT_TYPE', 'UNIT_TYPE_LABEL', 'TIME_FORMAT',
#        'TIME_FORMAT_LABEL', 'COMMENT_OBS', 'OBS_STATUS', 'OBS_STATUS_LABEL',
#        'OBS_CONF', 'OBS_CONF_LABEL'],
#       dtype='object')
#        STRUCTURE                STRUCTURE_ID ACTION FREQ FREQ_LABEL REF_AREA  \
# 0  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AGO
# 1  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AGO
# 2  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AGO
# 3  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      ALB
# 4  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      ALB
#
#   REF_AREA_LABEL             INDICATOR  \
# 0         Angola  WB_PIP_HEADCOUNT_IPL
# 1         Angola  WB_PIP_HEADCOUNT_IPL
# 2         Angola  WB_PIP_HEADCOUNT_IPL
# 3        Albania  WB_PIP_HEADCOUNT_IPL
# 4        Albania  WB_PIP_HEADCOUNT_IPL
#
#                                      INDICATOR_LABEL SEX  ... UNIT_MULT_LABEL  \
# 0  Poverty headcount ratio (2017 PPP, $2.15) (% o...  _T  ...           Units
# 1  Poverty headcount ratio (2017 PPP, $2.15) (% o...  _T  ...           Units
# 2  Poverty headcount ratio (2017 PPP, $2.15) (% o...  _T  ...           Units
# 3  Poverty headcount ratio (2017 PPP, $2.15) (% o...  _T  ...           Units
# 4  Poverty headcount ratio (2017 PPP, $2.15) (% o...  _T  ...           Units
#
#   UNIT_TYPE UNIT_TYPE_LABEL TIME_FORMAT TIME_FORMAT_LABEL COMMENT_OBS  \
# 0     RATIO           Ratio         602              CCYY         NaN
# 1     RATIO           Ratio         602              CCYY         NaN
# 2     RATIO           Ratio         602              CCYY         NaN
# 3     RATIO           Ratio         602              CCYY         NaN
# 4     RATIO           Ratio         602              CCYY         NaN
#
#   OBS_STATUS OBS_STATUS_LABEL OBS_CONF OBS_CONF_LABEL
# 0          A     Normal value       PU         Public
# 1          A     Normal value       PU         Public
# 2          A     Normal value       PU         Public
# 3          A     Normal value       PU         Public
# 4          A     Normal value       PU         Public
#
# [5 rows x 38 columns]
# Index(['STRUCTURE', 'STRUCTURE_ID', 'ACTION', 'FREQ', 'FREQ_LABEL', 'REF_AREA',
#        'REF_AREA_LABEL', 'INDICATOR', 'INDICATOR_LABEL', 'SEX', 'SEX_LABEL',
#        'AGE', 'AGE_LABEL', 'URBANISATION', 'URBANISATION_LABEL',
#        'UNIT_MEASURE', 'UNIT_MEASURE_LABEL', 'COMP_BREAKDOWN_1',
#        'COMP_BREAKDOWN_1_LABEL', 'COMP_BREAKDOWN_2', 'COMP_BREAKDOWN_2_LABEL',
#        'COMP_BREAKDOWN_3', 'COMP_BREAKDOWN_3_LABEL', 'TIME_PERIOD',
#        'OBS_VALUE', 'DATABASE_ID', 'DATABASE_ID_LABEL', 'UNIT_MULT',
#        'UNIT_MULT_LABEL', 'UNIT_TYPE', 'UNIT_TYPE_LABEL', 'TIME_FORMAT',
#        'TIME_FORMAT_LABEL', 'OBS_STATUS', 'OBS_STATUS_LABEL', 'OBS_CONF',
#        'OBS_CONF_LABEL'],
#       dtype='object')
#        STRUCTURE                STRUCTURE_ID ACTION FREQ FREQ_LABEL REF_AREA  \
# 0  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AFG
# 1  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AFG
# 2  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AFG
# 3  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      AFG
# 4  datastructure  WB.DATA360:DS_DATA360(1.2)      I    A     Annual      ALB
#
#   REF_AREA_LABEL           INDICATOR                     INDICATOR_LABEL SEX  \
# 0    Afghanistan  WB_LPGD_SE_LPV_POP  Population for Reference Year 2019  _T
# 1    Afghanistan  WB_LPGD_SE_LPV_POP  Population for Reference Year 2019  _T
# 2    Afghanistan  WB_LPGD_SE_LPV_POP  Population for Reference Year 2019  _T
# 3    Afghanistan  WB_LPGD_SE_LPV_POP  Population for Reference Year 2019  _T
# 4        Albania  WB_LPGD_SE_LPV_POP  Population for Reference Year 2019  _T
#
#    ... UNIT_MULT UNIT_MULT_LABEL UNIT_TYPE  UNIT_TYPE_LABEL TIME_FORMAT  \
# 0  ...         0           Units     COUNT  Count (Integer)         602
# 1  ...         0           Units     COUNT  Count (Integer)         602
# 2  ...         0           Units     COUNT  Count (Integer)         602
# 3  ...         0           Units     COUNT  Count (Integer)         602
# 4  ...         0           Units     COUNT  Count (Integer)         602
#
#   TIME_FORMAT_LABEL OBS_STATUS OBS_STATUS_LABEL OBS_CONF OBS_CONF_LABEL
# 0              CCYY          A     Normal value       PU         Public
# 1              CCYY          A     Normal value       PU         Public
# 2              CCYY          A     Normal value       PU         Public
# 3              CCYY          A     Normal value       PU         Public
# 4              CCYY          A     Normal value       PU         Public
#
# [5 rows x 37 columns]

# %%
#run
print(f"Poverty columns:\n{poverty.columns.tolist()}")
print(f"Learning Poverty columns:\n{learning_poverty.columns.tolist()}")
# Out:
# Poverty columns:
# ['STRUCTURE', 'STRUCTURE_ID', 'ACTION', 'FREQ', 'FREQ_LABEL', 'REF_AREA', 'REF_AREA_LABEL', 'INDICATOR', 'INDICATOR_LABEL', 'SEX', 'SEX_LABEL', 'AGE', 'AGE_LABEL', 'URBANISATION', 'URBANISATION_LABEL', 'UNIT_MEASURE', 'UNIT_MEASURE_LABEL', 'COMP_BREAKDOWN_1', 'COMP_BREAKDOWN_1_LABEL', 'COMP_BREAKDOWN_2', 'COMP_BREAKDOWN_2_LABEL', 'COMP_BREAKDOWN_3', 'COMP_BREAKDOWN_3_LABEL', 'TIME_PERIOD', 'OBS_VALUE', 'DATABASE_ID', 'DATABASE_ID_LABEL', 'UNIT_MULT', 'UNIT_MULT_LABEL', 'UNIT_TYPE', 'UNIT_TYPE_LABEL', 'TIME_FORMAT', 'TIME_FORMAT_LABEL', 'COMMENT_OBS', 'OBS_STATUS', 'OBS_STATUS_LABEL', 'OBS_CONF', 'OBS_CONF_LABEL']
# Learning Poverty columns:
# ['STRUCTURE', 'STRUCTURE_ID', 'ACTION', 'FREQ', 'FREQ_LABEL', 'REF_AREA', 'REF_AREA_LABEL', 'INDICATOR', 'INDICATOR_LABEL', 'SEX', 'SEX_LABEL', 'AGE', 'AGE_LABEL', 'URBANISATION', 'URBANISATION_LABEL', 'UNIT_MEASURE', 'UNIT_MEASURE_LABEL', 'COMP_BREAKDOWN_1', 'COMP_BREAKDOWN_1_LABEL', 'COMP_BREAKDOWN_2', 'COMP_BREAKDOWN_2_LABEL', 'COMP_BREAKDOWN_3', 'COMP_BREAKDOWN_3_LABEL', 'TIME_PERIOD', 'OBS_VALUE', 'DATABASE_ID', 'DATABASE_ID_LABEL', 'UNIT_MULT', 'UNIT_MULT_LABEL', 'UNIT_TYPE', 'UNIT_TYPE_LABEL', 'TIME_FORMAT', 'TIME_FORMAT_LABEL', 'OBS_STATUS', 'OBS_STATUS_LABEL', 'OBS_CONF', 'OBS_CONF_LABEL']

# %%
#rename
poverty.rename(columns={"TIME_PERIOD": "year"}, inplace=True)
learning_poverty.rename(columns={"TIME_PERIOD": "year"}, inplace=True)


print("poverty columns after rename:", poverty.columns)
print("learning_proverty columns after rename:", learning_poverty.columns)
# Out:
# poverty columns after rename: Index(['STRUCTURE', 'STRUCTURE_ID', 'ACTION', 'FREQ', 'FREQ_LABEL', 'REF_AREA',
#        'REF_AREA_LABEL', 'INDICATOR', 'INDICATOR_LABEL', 'SEX', 'SEX_LABEL',
#        'AGE', 'AGE_LABEL', 'URBANISATION', 'URBANISATION_LABEL',
#        'UNIT_MEASURE', 'UNIT_MEASURE_LABEL', 'COMP_BREAKDOWN_1',
#        'COMP_BREAKDOWN_1_LABEL', 'COMP_BREAKDOWN_2', 'COMP_BREAKDOWN_2_LABEL',
#        'COMP_BREAKDOWN_3', 'COMP_BREAKDOWN_3_LABEL', 'year', 'OBS_VALUE',
#        'DATABASE_ID', 'DATABASE_ID_LABEL', 'UNIT_MULT', 'UNIT_MULT_LABEL',
#        'UNIT_TYPE', 'UNIT_TYPE_LABEL', 'TIME_FORMAT', 'TIME_FORMAT_LABEL',
#        'COMMENT_OBS', 'OBS_STATUS', 'OBS_STATUS_LABEL', 'OBS_CONF',
#        'OBS_CONF_LABEL'],
#       dtype='object')
# learning_proverty columns after rename: Index(['STRUCTURE', 'STRUCTURE_ID', 'ACTION', 'FREQ', 'FREQ_LABEL', 'REF_AREA',
#        'REF_AREA_LABEL', 'INDICATOR', 'INDICATOR_LABEL', 'SEX', 'SEX_LABEL',
#        'AGE', 'AGE_LABEL', 'URBANISATION', 'URBANISATION_LABEL',
#        'UNIT_MEASURE', 'UNIT_MEASURE_LABEL', 'COMP_BREAKDOWN_1',
#        'COMP_BREAKDOWN_1_LABEL', 'COMP_BREAKDOWN_2', 'COMP_BREAKDOWN_2_LABEL',
#        'COMP_BREAKDOWN_3', 'COMP_BREAKDOWN_3_LABEL', 'year', 'OBS_VALUE',
#        'DATABASE_ID', 'DATABASE_ID_LABEL', 'UNIT_MULT', 'UNIT_MULT_LABEL',
#        'UNIT_TYPE', 'UNIT_TYPE_LABEL', 'TIME_FORMAT', 'TIME_FORMAT_LABEL',
#        'OBS_STATUS', 'OBS_STATUS_LABEL', 'OBS_CONF', 'OBS_CONF_LABEL'],
#       dtype='object')

# %%
#filter datasets
poverty_filtered = poverty[poverty['INDICATOR_LABEL'].str.contains('Poverty headcount ratio', case=False)]
learning_filtered = learning_poverty[learning_poverty['INDICATOR_LABEL'].str.contains('Learning poverty', case=False)]

# %%
#merge datasets
merged = pd.merge(poverty_filtered, learning_filtered, on=["REF_AREA_LABEL", "year"], how="inner", suffixes=("_poverty", "_learning"))

print("Merged shape:", merged.shape)
print(merged[['REF_AREA_LABEL', 'year', 'INDICATOR_LABEL_poverty', 'OBS_VALUE_poverty', 'INDICATOR_LABEL_learning', 'OBS_VALUE_learning']].head())
# Out:
# Merged shape: (8100, 73)
#   REF_AREA_LABEL  year                            INDICATOR_LABEL_poverty  \
# 0      Argentina  2006  Poverty headcount ratio (2017 PPP, $2.15) (% o...
# 1      Argentina  2006  Poverty headcount ratio (2017 PPP, $2.15) (% o...
# 2      Argentina  2006  Poverty headcount ratio (2017 PPP, $2.15) (% o...
# 3      Argentina  2006  Poverty headcount ratio (2017 PPP, $2.15) (% o...
# 4      Argentina  2006  Poverty headcount ratio (2017 PPP, $2.15) (% o...
#
#    OBS_VALUE_poverty                           INDICATOR_LABEL_learning  \
# 0               2.17  Learning poverty: Share of Children at the End...
# 1               2.17  Learning poverty: Share of Children at the End...
# 2               2.17  Learning poverty: Share of Children at the End...
# 3               2.17                               Learning Poverty Gap
# 4               2.17                               Learning Poverty Gap
#
#    OBS_VALUE_learning
# 0           55.528942
# 1           52.871078
# 2           58.131767
# 3            0.675867
# 4            0.672008

# %%
# (1d) descrptive statistics
print("\nPoverty dataset descriptive stats:")
display(poverty_clean.describe(include="all"))

print("\nLearning Poverty dataset descriptive stats:")
display(learning_clean.describe(include="all"))

poverty_clean.to_csv("poverty_clean.csv", index=False)
learning_clean.to_csv("learning_poverty_clean.csv", index=False)

print("\n Cleaned datasets saved as 'poverty_clean.csv' and 'learning_poverty_clean.csv'")
# Out:
# Poverty dataset descriptive stats:
#        REF_AREA_LABEL   TIME_PERIOD  \
# count           29973  29973.000000
# unique            184           NaN
# top     United States           NaN
# freq              720           NaN
# mean              NaN   2006.058353
# std               NaN     10.952783
# min               NaN   1963.000000
# 25%               NaN   1999.000000
# 50%               NaN   2008.000000
# 75%               NaN   2015.000000
# max               NaN   2023.000000
#
#                                           INDICATOR_LABEL     OBS_VALUE
# count                                               29973  29973.000000
# unique                                                  6           NaN
# top     Population living below the poverty line (2017...           NaN
# freq                                                 5067           NaN
# mean                                                  NaN     65.928055
# std                                                   NaN    307.901574
# min                                                   NaN      0.000000
# 25%                                                   NaN      0.211968
# 50%                                                   NaN      2.000000
# 75%                                                   NaN     22.820000
# max                                                   NaN   4288.065430
# Learning Poverty dataset descriptive stats:
#        REF_AREA_LABEL  TIME_PERIOD                     INDICATOR_LABEL  \
# count            9329   9329.00000                                9329
# unique            125          NaN                                   9
# top           Armenia          NaN  Population for Reference Year 2019
# freq              180          NaN                                3154
# mean              NaN   2012.56587                                 NaN
# std               NaN      6.47011                                 NaN
# min               NaN   2001.00000                                 NaN
# 25%               NaN   2006.00000                                 NaN
# 50%               NaN   2013.00000                                 NaN
# 75%               NaN   2019.00000                                 NaN
# max               NaN   2023.00000                                 NaN
#
#            OBS_VALUE
# count   9.329000e+03
# unique           NaN
# top              NaN
# freq             NaN
# mean    1.027544e+06
# std     6.183394e+06
# min     0.000000e+00
# 25%     1.473900e+00
# 50%     2.616992e+01
# 75%     3.256470e+05
# max     3.016007e+08
#  Cleaned datasets saved as 'poverty_clean.csv' and 'learning_poverty_clean.csv'

# %%
# Insights 
print("\n--- Insights ---")
print("1. Both datasets contain missing values, mainly in numeric columns, which were filled with mean values.")
print("2. Descriptive stats show average poverty rates and spread across countries.")
print("3. Some countries show significantly higher learning poverty compared to global averages.")
print("4. Constant columns such as 'UNIT_MULT_x' and 'TIME_FORMAT_x' were identified and removed due to zero variance, improving dataset efficiency.")
print("5. A strong correlation between 'OBS_VALUE_x' and 'OBS_VALUE_y' suggests potential redundancy in poverty-related indicators.")
print("6. Temporal coverage from 2000 to 2020 enables trend analysis and assessment of progress toward education and poverty reduction.")
print("7. Countries with both high poverty and high learning poverty rates may require integrated policy interventions focused on early childhood education and social protection.")
# Out:
# --- Insights ---
# 1. Both datasets contain missing values, mainly in numeric columns, which were filled with mean values.
# 2. Descriptive stats show average poverty rates and spread across countries.
# 3. Some countries show significantly higher learning poverty compared to global averages.
# 4. Constant columns such as 'UNIT_MULT_x' and 'TIME_FORMAT_x' were identified and removed due to zero variance, improving dataset efficiency.
# 5. A strong correlation between 'OBS_VALUE_x' and 'OBS_VALUE_y' suggests potential redundancy in poverty-related indicators.
# 6. Temporal coverage from 2000 to 2020 enables trend analysis and assessment of progress toward education and poverty reduction.
# 7. Countries with both high poverty and high learning poverty rates may require integrated policy interventions focused on early childhood education and social protection.

# %% [markdown]
# # ==========================================================
# # 2. NUMERICAL ANALYSIS (20 marks)
# # ==========================================================

# %%
#(2a) convert to numpy arrays and calculate mean, median, standard-dev
poverty_array = poverty["OBS_VALUE"].to_numpy()
learning_array = learning_poverty["OBS_VALUE"].to_numpy()
print("Poverty array:\n", poverty_array)
print("Learning poverty array:\n", learning_array)
print("")

# mean
poverty_mean = np.mean(poverty_array)
learning_mean = np.mean(learning_array)
print("Average Poverty Value:", poverty_mean)
print("Average Learning Poverty Value:", learning_mean)
print("")

# median
poverty_median = np.median(poverty_array)
learning_median = np.median(learning_array)
print("Median Poverty Value:", poverty_median)
print("Median Learning Poverty Value:", learning_median)
print("")

# standard deviation
poverty_std = np.std(poverty_array)
learning_std = np.std(learning_array)
print("Poverty Standard Deviation:", poverty_std)
print("Learning Poverty Standard Deviation:", learning_std)
# Out:
# Poverty array:
#  [ 21.36        14.59        31.12       ... 801.36499023 689.65124512
#  663.31634521]
# Learning poverty array:
#  [1.23284100e+07 1.00631200e+06 4.97853600e+06 ... 5.33453369e+00
#  9.72284698e+00 1.48964615e+01]
#
# Average Poverty Value: 65.92805522835705
# Average Learning Poverty Value: 1027543.7196741579
#
# Median Poverty Value: 2.0
# Median Learning Poverty Value: 26.169919967651367
#
# Poverty Standard Deviation: 307.8964380515006
# Learning Poverty Standard Deviation: 6183062.796078254

# %%
# (2b) reshape arrays
poverty_matrix = poverty_array.reshape(-1, 1)
learning_matrix = learning_array.reshape(-1, 1)

# array operations
sum_array = poverty_array[:10] + learning_array[:10]   
diff_array = poverty_array[:10] - learning_array[:10]

# making sure arrays are the same length
min_len = min(len(poverty_array), len(learning_array))

# Differences (poverty - learning)
diff = poverty_array[:min_len] - learning_array[:min_len]
print("First 10 differences (Poverty - Learning):\n", diff[:10])
print("")

# year-to-year percentage change for both datasets
poverty_change = pd.Series(poverty_array).pct_change() * 100
poverty_change = poverty_change.fillna(0)  # Replace NaNs with 0
learning_change = pd.Series(learning_array).pct_change() * 100
learning_change = learning_change.fillna(0)
print("Yearly % change in poverty:\n", poverty_change.head(10))
print("")
print("Yearly % change in learning poverty:\n", learning_change.head(10))
# Out:
# First 10 differences (Poverty - Learning):
#  [-12328388.64  -1006297.41  -4978504.88  -5053476.97   -408851.41
#     -32056.41   -167689.8     -96962.88   -985701.48   -486507.4 ]
#
# Yearly % change in poverty:
#  0      0.000000
# 1    -31.694757
# 2    113.296779
# 3    -98.296915
# 4    105.660377
# 5    -45.871560
# 6    -66.101695
# 7    210.000000
# 8     64.516129
# 9    -90.196078
# dtype: float64
#
# Yearly % change in learning poverty:
#  0      0.000000
# 1    -91.837455
# 2    394.730859
# 3      1.505292
# 4    -91.909482
# 5    -92.159275
# 6    423.099479
# 7    -42.176934
# 8    916.570668
# 9    -50.643577
# dtype: float64

# %%
# (2c) Findings
print("\n--- Findings ---")
print("1. NumPy analysis shows the central tendency (mean, median) and spread (std dev) of the datasets.")
print("2. Reshaping allows us to prepare data for matrix-style operations.")
print("3. Element-wise operations highlight differences in poverty and learning poverty rates for matching entries.")

#correlation
corr = np.corrcoef(poverty_array[:min_len], learning_array[:min_len])[0, 1]
print("4. Correlation between Poverty and Learning:", corr)
# Out:
# --- Findings ---
# 1. NumPy analysis shows the central tendency (mean, median) and spread (std dev) of the datasets.
# 2. Reshaping allows us to prepare data for matrix-style operations.
# 3. Element-wise operations highlight differences in poverty and learning poverty rates for matching entries.
# 4. Correlation between Poverty and Learning: -0.05838204022457177

# %% [markdown]
# # ==========================================================
# # 3. Visualisation (20 marks)
# # ==========================================================

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")
import os 
import pandas as pd

# %%
#(3a) barplot poverty vs learning poverty

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

avg_poverty = poverty["OBS_VALUE"].mean()
avg_learning_poverty = learning_poverty["OBS_VALUE"].mean()

data = pd.DataFrame({"Category": ["Poverty", "Learning Poverty"],"Average Value": [avg_poverty, avg_learning_poverty]})
plt.figure(figsize=(6, 4))
sns.barplot(data=data, x="Category", y="Average Value", palette="Blues_d")
plt.yscale("log")
plt.title("Average Values (Log Scale): Poverty vs Learning Poverty")
plt.ylabel("Average OBS_VALUE (log scale)")
plt.xlabel("")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18256\3816430851.py:12: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=data, x="Category", y="Average Value", palette="Blues_d")

# %%
#(3b) boxplot distribution comparison

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

df = pd.DataFrame({"OBS_VALUE": pd.to_numeric(pd.concat([poverty["OBS_VALUE"], learning_poverty["OBS_VALUE"]], ignore_index=True),
        errors="coerce" ),"Category": ["Poverty"] * len(poverty) + ["Learning Poverty"] * len(learning_poverty)})
df.dropna(subset=["OBS_VALUE"], inplace=True)

plt.figure(figsize=(8, 5))
sns.boxplot(data=df, x="Category", y="OBS_VALUE", palette="Blues", showfliers=False)
plt.yscale("log")
plt.title("Distribution Comparison: Poverty vs Learning Poverty (Log Scale, No Outliers)")
plt.ylabel("OBS_VALUE (log scale)")
plt.xlabel("")
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_18256\2404199813.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x="Category", y="OBS_VALUE", palette="Blues", showfliers=False)

# %%
#3. Histogram – Value Distribution

poverty_log = np.log10(poverty["OBS_VALUE"][poverty["OBS_VALUE"] > 0])
learning_log = np.log10(learning_poverty["OBS_VALUE"][learning_poverty["OBS_VALUE"] > 0])

plt.figure(figsize=(12, 5))

# Poverty Histogram
plt.subplot(1, 2, 1)
plt.hist(poverty_log, bins=40, color="skyblue", edgecolor="black")
plt.title("Poverty Value Distribution (Log10)")
plt.xlabel("log10(OBS_VALUE)")
plt.ylabel("Frequency")

# Learning Poverty Histogram
plt.subplot(1, 2, 2)
plt.hist(learning_log, bins=30, color="salmon", edgecolor="black")
plt.title("Learning Poverty Value Distribution (Log10)")
plt.xlabel("log10(OBS_VALUE)")
plt.ylabel("Frequency")

plt.tight_layout()
plt.show()

# %%
#4. Scatter Plot – Correlation Between Poverty & Learning Poverty
plt.figure(figsize=(6, 5)) 
sns.scatterplot(data=merged, x="OBS_VALUE_poverty", y="OBS_VALUE_learning", alpha=0.5) 
plt.title("Poverty vs Learning Poverty") 
plt.xlabel("Poverty OBS_VALUE") 
plt.ylabel("Learning Poverty OBS_VALUE") 
plt.show()
